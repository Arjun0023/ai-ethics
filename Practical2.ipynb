# %%
# Lab2:- Experiment the regression model without bias and with bias.

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
#1)load the dataset
df = pd.read_csv('/content/Iris.csv')
print(df.head(150))
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#2 data preparation
df_encoded = pd.get_dummies(df, drop_first=True)
print("")

print(df_encoded)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#      Species_Iris-versicolor  Species_Iris-virginica
# 0                      False                   False
# 1                      False                   False
# 2                      False                   False
# 3                      False                   False
# 4                      False                   False
# ..                       ...                     ...
# 145                    False                    True
# 146                    False                    True
# 147                    False                    True
# 148                    False                    True
# 149                    False                    True
#
# [150 rows x 7 columns]

# %%
print(df_encoded.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species_Iris-versicolor', 'Species_Iris-virginica'],
#       dtype='object')

# %%
x = df_encoded.drop(columns=['SepalLengthCm'])
y = df_encoded['SepalLengthCm']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,
random_state=42)
print(x)
# Out:
#       Id  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species_Iris-versicolor  \
# 0      1           3.5            1.4           0.2                    False
# 1      2           3.0            1.4           0.2                    False
# 2      3           3.2            1.3           0.2                    False
# 3      4           3.1            1.5           0.2                    False
# 4      5           3.6            1.4           0.2                    False
# ..   ...           ...            ...           ...                      ...
# 145  146           3.0            5.2           2.3                    False
# 146  147           2.5            5.0           1.9                    False
# 147  148           3.0            5.2           2.0                    False
# 148  149           3.4            5.4           2.3                    False
# 149  150           3.0            5.1           1.8                    False
#
#      Species_Iris-virginica
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ..                      ...
# 145                    True
# 146                    True
# 147                    True
# 148                    True
# 149                    True
#
# [150 rows x 6 columns]

# %%
print(y)
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
#3 train model without bias(intercept)
model_without_bias = LinearRegression(fit_intercept=False)
model_without_bias.fit(x_train, y_train)
# Out:
# LinearRegression(fit_intercept=False)

# %%
#4 train model with bias (intercept)
model_with_bias = LinearRegression(fit_intercept=True)
model_with_bias.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#5 make Prediction
y_pred_without_bias = model_without_bias.predict(x_test)
y_pred_with_bias = model_with_bias.predict(x_test)
#6 evaluate the models
mse_without_bias = mean_squared_error(y_test, y_pred_without_bias)
mse_with_bias = mean_squared_error(y_test, y_pred_with_bias)
print("Mean Squared Error (MSE) without bias:", mse_without_bias)
print("Mean Squared Error (MSE) with bias:", mse_with_bias)
# Out:
# Mean Squared Error (MSE) without bias: 0.1488341737791438
# Mean Squared Error (MSE) with bias: 0.09601875857943924
